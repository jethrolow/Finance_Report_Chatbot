# %% [markdown]
# # Data Preprocessing

# %%
# Import libraries
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.schema import(
    AIMessage,
    HumanMessage,
    SystemMessage
)
from langchain.prompts import PromptTemplate
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate
)
from langchain.chains import LLMChain
from langchain.agents import AgentType, initialize_agent, load_tools
from langchain import OpenAI, ConversationChain
from langchain.memory import ConversationBufferWindowMemory, ConversationBufferMemory
from langchain.utilities import SerpAPIWrapper
from langchain.agents import Tool
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader
from langchain.chains.question_answering import load_qa_chain
from langchain.chains import ConversationalRetrievalChain
from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.text_splitter import CharacterTextSplitter, RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.vectorstores import FAISS
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader

import tabula

import os

from PyPDF2 import PdfReader
import pandas as df

# %%
# load in openai API key
os.environ['OPENAI_API_KEY'] =""

# %% [markdown]
# ## Document used and test cases
#
# For the purpose of experimentation, let's use the Tesla Annual Report for year 2022. This document contains both text and tabular information (at the end of document), hence it will be a good test document for our prompt engineering. The document is stored in the "./data" folder.
#
# We should also include some basic test cases beforehand. This will make it easy to check if the prompts are giving us the correct output. Some test cases are defined here for reference.
#
# * Numbers. To test tabular data.
#
# 1. What are the total assets and liabilities for the year 2022? Answer: 82338 million and 36440 million.
# 1. What is the Income before income taxes for the year  2020, 2021 and 2022? Answer: 1,154, 6,343 and 13,719 respectively.
# 1. What is the year on year increase in the gross profit from 2020 to 2022 in percentages? Answer: 105.2% and 53.3% respectively.
# Note: This tests the higher level logical thinking of the model.
# 1. What is the gross profit in 2019?
# Note: This tests if the model will give a truthful answer or hallucinates the numbers.
#
# * General Questions (open-ended)
# 1. What does Tesla do? And what types of businesses is Tesla involved in?
# 1. How is the financial health of Tesla?
# 1. What kind of technologies does Tesla invest in?

# %%
# template code to be used for testing of prompts
query_1 = "What are the total assets and liabilities for the year 2022 in the consolidated balance sheet?"
query_2 = "What is the Income before income taxes for the year  2020, 2021 and 2022?"
query_3 = "What is the year on year increase in the gross profit from 2020 to 2022 in percentages?"
query_4 = "What is the gross profit in 2019?"
queries_num = [query_1,query_2,query_3,query_4]

query_5 = "What does Tesla do? And what types of businesses is Tesla involved in?"
query_6 = "How is the financial health of Tesla?"
query_7 = "What kind of technologies does Tesla invest in?"
queries_gen = [query_5, query_6, query_7]

# %% [markdown]
# ## Verify tabular data integrity
#
# As the tables are all converted to a string of text before passing to the embedding model, we need to check if the model can still understand the structured information.

# %%
# read in the information from the Tesla Annual Report, convert to embeddings and store in vectorestore
# using Langchain PyPDFLoader
# Note: PyPDFLoader is for structured data extraction
FILE_PATH = "../data/Tesla_Annual_Report_2022.pdf"
loader = PyPDFLoader(FILE_PATH)
data = loader.load()
print (f'You have {len(data)} pages in your pdf')
# Out:
# You have 184 pages in your pdf

# %%
embeddings = OpenAIEmbeddings()
vector_store = FAISS.from_documents(data, embeddings)

# %%
qa = RetrievalQA.from_chain_type(llm=ChatOpenAI(temperature = 0.1), chain_type="stuff", retriever=vector_store.as_retriever())
for query in queries_num:
    print(query)
    print(qa.run(query))
    print("---------------------------------")
# Out:
# What are the total assets and liabilities for the year 2022?
# The total assets for the year 2022 are $82,338 million. The total liabilities for the year 2022 are $36,440 million.
# ---------------------------------
# What is the Income before income taxes for the year  2020, 2021 and 2022?
# The income before income taxes for the years 2020, 2021, and 2022 are as follows:
#
# - 2020: $1,154 million
# - 2021: $6,343 million
# - 2022: $13,719 million
# ---------------------------------
# What is the year on year increase in the gross profit from 2020 to 2022 in percentages?
# The information provided does not directly state the gross profit for the years 2020 and 2022. Therefore, I cannot determine the year-on-year increase in gross profit from 2020 to 2022 in percentages.
# ---------------------------------
# What is the gross profit in 2019?
# The given context does not provide information about the gross profit in 2019.
# ---------------------------------

# %% [markdown]
# **Observations**
# * The model is able to read the tabular data that has been read in and embedded. This is what we want to verify.
# * This is what we expected as PyPDFLoader is a structured data extraction. Tables are considered as structured data.
# * The base embedding and chat model is already quite good. It can give accurate information and does not give answers it does not know.
# * On higher level tasks, it seems to lose the contextual information.
# * Some of the information like the gross profit are not included.

# %% [markdown]
# Let's try a different package to read in the data. The package is PyPDF2 --> PdfReader. Note that PyPDF2 is inherently for structured data extraction.

# %%
def get_text_from_pdf(fs_pdf_docs: list):
    text_output = ""
    for pdf_file in fs_pdf_docs:
        pdf_reader = PdfReader(pdf_file)
        for page in pdf_reader.pages:
            text_output = text_output + page.extract_text()
    return text_output

def get_chunk_from_text(whole_text: str):
    text_split = RecursiveCharacterTextSplitter(
        separators = ["\n\n", "\n", " ", ""],
        chunk_size = 1000,
        chunk_overlap = 200,
        length_function = len
    )
    chunks = text_split.split_text(whole_text)
    return chunks

def get_vectorstore_from_chucks(chunks):
    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_texts(texts = chunks, embedding = embeddings)
    return vectorstore

# %%
text = get_text_from_pdf([FILE_PATH])
chunks = get_chunk_from_text(text)
vector_store = get_vectorstore_from_chucks(chunks)

# %%
qa = RetrievalQA.from_chain_type(llm=ChatOpenAI(temperature = 0.1), chain_type="stuff", retriever=vector_store.as_retriever())
for query in queries_num:
    print(query)
    print(qa.run(query))
    print("---------------------------------")
# Out:
# What are the total assets and liabilities for the year 2022?
# The total assets for the year 2022 are $82,338 million. The total liabilities for the year 2022 are $36,440 million.
# ---------------------------------
# What is the Income before income taxes for the year  2020, 2021 and 2022?
# The income before income taxes for the years 2020, 2021, and 2022 are as follows:
#
# - 2020: $1,154 million
# - 2021: $6,343 million
# - 2022: $13,719 million
# ---------------------------------
# What is the year on year increase in the gross profit from 2020 to 2022 in percentages?
# The year-on-year increase in gross profit from 2020 to 2022 cannot be determined based on the provided information. The gross profit figures for 2020 are not given in the context.
# ---------------------------------
# What is the gross profit in 2019?
# The information provided does not include the gross profit for the year 2019.
# ---------------------------------

# %% [markdown]
# **Observations:**
# * The output using PyPDF2 is the same as using PyPDFLoader. This is also expected as PdfReader is a structured data extractor.
# * Hence, we can use PyPDF2 for the app as it allows for file type object loading with is not possible with PyPDFLoader.

# %% [markdown]
# ## Secondary reference for tabular data
# To provide a secondary module to extract the tabular data and acts as a source of reference to ground the context for the prompts.
# methods:
# 1. Use prompt to extract to extract tabular data
# 1. Use camelot package to extract tabular data

# %%
# # creating a prompt to extract the tables as a csv format for further grounding of the information
# query = "Using the context provided, please extract all the tabular data in the report and output the tabular data in a csv file format"
# qa = load_qa_chain(llm=ChatOpenAI(temperature = 0.1), chain_type="map_reduce")
# qa.run(input_documents=data, question=query)

# Does not work, take too long for map_reduce. "stuff" exceeds the max token length

# %%
tables = camelot.read_pdf(FILE_PATH, flavor='stream', pages ="all")
# Out:
# /home/jethro/anaconda3/envs/langchain/lib/python3.11/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/jethro/anaconda3/envs/langchain/lib/python3.11/site-packages/camelot/parsers/stream.py:453: UserWarning: No tables found on page-2
#   warnings.warn(f"No tables found on {base_filename}")
# /home/jethro/anaconda3/envs/langchain/lib/python3.11/site-packages/camelot/parsers/stream.py:453: UserWarning: No tables found on page-183
#   warnings.warn(f"No tables found on {base_filename}")

# %%
print(len(tables))
tables[190].df
# Out:
# 222
#                                          0  \
# 0                   Note 14 – Income Taxes
# 1
# 2
# 3
# 4
# 5
# 6                                 Domestic
# 7   Noncontrolling interest and redeemable
# 8                  noncontrolling interest
# 9                                  Foreign
# 10              Income before income taxes
# 11
# 12                following (in millions):
# 13
# 14
# 15                                Current:
# 16                                 Federal
#
#                                                     1       2  \
# 0
# 1   A provision for income taxes of $1.13 billion,...
# 2   December 31, 2022, 2021 and 2020, respectively...
# 3   provision for income taxes for the years ended...
# 4
# 5                                                        2022
# 6                                                   $   5,524
# 7
# 8                                                          31
# 9                                                       8,164
# 10                                                  $  13,719
# 11  The components of the provision for income tax...
# 12
# 13
# 14                                                       2022
# 15
# 16                                                  $       —
#
#                           3     4      5  6     7      8
# 0
# 1
# 2
# 3
# 4   Year Ended December 31,
# 5                            2021            2020
# 6                         $        (130)  $        (198)
# 7
# 8                                    125             141
# 9                                  6,348           1,211
# 10                        $        6,343  $        1,154
# 11
# 12
# 13  Year Ended December 31,
# 14                           2021            2020
# 15
# 16                        $            —  $            —

# %% [markdown]
# **Observations:**
# * As can be seen, there are 222 tables generated, which is a lot.
# * Upon inspection, it is found that there are many tables which are actually general tables and not relevant to financial data.
# * Hence, we need a search function to find only relevant pages to pass to the camelot module for table extraction

# %%
# read in the information from the Tesla Annual Report, convert to embeddings and store in vectorestore
# using Langchain PyPDFLoader
# Note: PyPDFLoader is for structured data extraction
FILE_PATH = "../data/Tesla_Annual_Report_2022.pdf"
loader = PyPDFLoader(FILE_PATH)
data = loader.load()
print (f'You have {len(data)} pages in your pdf')
type(data[0].page_content)
# Out:
# You have 184 pages in your pdf
# str

# %%
def find_financial_report(documents):
    page_num_string = ""
    search_words = ["balance sheet", "income statement", "statement of cash flow", "statement of retained earnings"]
    for index, page in enumerate(documents):
        string_content = page.page_content.lower()
        if any(map(string_content.__contains__, search_words)):
            page_num_string += str(index+1)+","
    if page_num_string[-1]==",":
        page_num_string = page_num_string.rstrip(page_num_string[-1])
    return page_num_string

# %%
page_number = find_financial_report(data) # we now have a string of pages that we can pass to camelot to extract the relevant data

# %%
tables = camelot.read_pdf(FILE_PATH, flavor='stream', pages =page_number)
len(tables)
# Out:
# /home/jethro/anaconda3/envs/langchain/lib/python3.11/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# 28

# %%
tables[24].df
# Out:
#                                                     0  \
# 0
# 1                        consolidated balance sheets:
# 2
# 3                                   Operating leases:
# 4                 Operating lease right-of-use assets
# 5                       Accrued liabilities and other
# 6                         Other long-term liabilities
# 7                   Total operating lease liabilities
# 8                                     Finance leases:
# 9                           Solar energy systems, net
# 10                 Property, plant and equipment, net
# 11                         Total finance lease assets
# 12  Current portion of long-term debt and finance ...
# 13  Long-term debt and finance leases, net of curr...
# 14                    Total finance lease liabilities
#
#                                                     1                  2  3  \
# 0   The balances for the operating and finance lea...
# 1
# 2                                                      December 31, 2022
# 3
# 4                                                   $              2,563  $
# 5                                                   $                485  $
# 6                                                                  2,164
# 7                                                   $              2,649  $
# 8
# 9                                                   $                 25  $
# 10                                                                 1,094
# 11                                                  $              1,119  $
# 12                                                  $                486  $
# 13                                                                   568
# 14                                                  $              1,054  $
#
#                     4
# 0
# 1
# 2   December 31, 2021
# 3
# 4               2,016
# 5                 368
# 6               1,671
# 7               2,039
# 8
# 9                  27
# 10              1,536
# 11              1,563
# 12                501
# 13                991
# 14              1,492

# %%
tables[19].df
# Out:
#                                                     0  1             2  \
# 0   Our solar energy systems, net, consisted of th...
# 1                                                         December 31,
# 2                                                                 2022
# 3                     Solar energy systems in service  $         6,785
# 4   Initial direct costs related to customer solar...
# 5                      system lease acquisition costs              104
# 6                                                                6,889
# 7   Less: accumulated depreciation and amortizatio...          (1,418)
# 8                                                                5,471
# 9             Solar energy systems under construction                2
# 10       Solar energy systems pending interconnection               16
# 11                      Solar energy systems, net (2)  $         5,489
#
#                3
# 0
# 1   December 31,
# 2           2021
# 3       $\n6,809
# 4
# 5            104
# 6          6,913
# 7        (1,187)
# 8          5,726
# 9             18
# 10            21
# 11      $\n5,765

# %%
# store the text of the dataframe into the vectorstore as embeddings
df_list = []
for table in tables:
    df = table.df
    text = df.to_string()
    df_list.append(text)
vectorstore = FAISS.from_texts(texts = df_list, embedding = embeddings)

# %% [markdown]
# **Observations:**
# * Many of the tables are missing the headers and the "millions". There are also still many incomplete tables.
# * This could cause the model performance to degrade due to inaccurate data being added to the vector store.
# * Further effort is needed to properly extract the tables from the pdf documents. Can try other packages.
# * Perhaps also can consider CV models for extracting tabular information.

# %% [markdown]
# ## Module to check if document is indeed a financial report or not
#
# To pass a prompt to classify the financial report as true or false. If the documents passed into the model are indeed not financial reports, to then give a warning to user so that he/she knows the output might not be correct.

# %%
FILE_PATH = "../data/Tesla_Annual_Report_2022.pdf"
loader = PyPDFLoader(FILE_PATH)
data = loader.load()
print (f'You have {len(data)} pages in your pdf')
# Out:
# You have 184 pages in your pdf

# %%
embeddings = OpenAIEmbeddings()
vector_store = FAISS.from_documents(data, embeddings)
qa = RetrievalQA.from_chain_type(llm=ChatOpenAI(temperature = 0.1), chain_type="stuff", retriever=vector_store.as_retriever())

# %%
# inspect the default template in RetreievalQA
qa.combine_documents_chain
# Out:
# StuffDocumentsChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, input_key='input_documents', output_key='output_text', llm_chain=LLMChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, prompt=ChatPromptTemplate(input_variables=['context', 'question'], output_parser=None, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], output_parser=None, partial_variables={}, template="Use the following pieces of context to answer the users question. \nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n----------------\n{context}", template_format='f-string', validate_template=True), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], output_parser=None, partial_variables={}, template='{question}', template_format='f-string', validate_template=True), additional_kwargs={})]), llm=ChatOpenAI(verbose=False, callbacks=None, callback_manager=None, tags=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo', temperature=0.1, model_kwargs={}, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='', request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None), output_key='text', output_parser=NoOpOutputParser(), return_final_only=True, llm_kwargs={}), document_prompt=PromptTemplate(input_variables=['page_content'], output_parser=None, partial_variables={}, template='{page_content}', template_format='f-string', validate_template=True), document_variable_name='context', document_separator='\n\n')

# %%
system_template = """Use the following pieces of context to answer the users question.\
No matter what the question is, you should always answer it as truthfully and accurately as possible\\
If you don't know the answer, just say that "I don't know", don't try to make up an answer.\
Your task is to classify if the report is a financial report or not a financial report.\
Again, your task is to classify if the report is a financial report or not a financial report.\
----------------
{context}"""

messages = [
    SystemMessagePromptTemplate.from_template(system_template),
    HumanMessagePromptTemplate.from_template("{question}\Classification:"),
]
prompt = ChatPromptTemplate.from_messages(messages)
chain_type_kwargs = {"prompt": prompt}

# %%
qa = RetrievalQA.from_chain_type(llm=OpenAI(temperature=0.0), chain_type="stuff", retriever=vector_store.as_retriever(), chain_type_kwargs=chain_type_kwargs)
query = "Please classify if the report is a financial report or not a financial report"
qa.run(query)
# Out:
# '.\n\nNo, this is not a financial report.'

# %% [markdown]
# Let's gather 5 reports, of which 3 are financial report and 2 are not financial reports. To observe if the LLM can actually discern it accurately.

# %%
DOC_CC = "../data/Cocacola_earningsrelease2022.pdf"
DOC_DESSERT = "../data/Dessert Lovers Foodbook 2016.pdf"
DOC_DISNEY = "../data/Disney_2022-Annual-Report.pdf"
DOC_FLATTIRE = "../data/How-to-Change-a-Flat-Tire-Student-Handout.pdf"
DOC_TESLA = "../data/Tesla_Annual_Report_2022.pdf"

# %%
def classify_report(filepath, chain_type_kwargs):
    loader = PyPDFLoader(filepath)
    data = loader.load()

    embeddings = OpenAIEmbeddings()
    vector_store = FAISS.from_documents(data, embeddings)
    qa = RetrievalQA.from_chain_type(llm=ChatOpenAI(temperature = 0.1), chain_type="stuff", retriever=vector_store.as_retriever(), chain_type_kwargs=chain_type_kwargs)

    query = "Please classify if the report is a financial report or not a financial report"
    print(filepath)
    return qa.run(query)

# %%
doc_list = [DOC_CC, DOC_DESSERT, DOC_DISNEY, DOC_FLATTIRE, DOC_TESLA]
for report in doc_list:
    print(classify_report(report, chain_type_kwargs))
    print("---------------------------------------")
# Out:
# ../data/Cocacola_earningsrelease2022.pdf
# Financial report
# ---------------------------------------
# ../data/Dessert Lovers Foodbook 2016.pdf
# Not a financial report
# ---------------------------------------
# ../data/Disney_2022-Annual-Report.pdf
# Financial report
# ---------------------------------------
# ../data/How-to-Change-a-Flat-Tire-Student-Handout.pdf
# Not a financial report
# ---------------------------------------
# ../data/Tesla_Annual_Report_2022.pdf
# Financial report
# ---------------------------------------

# %% [markdown]
# **Observations:**
# * After some tweaking of the prompt, the LLM is able to give consistently correctly answers on whether the report is or is not a financial report.

# %% [markdown]
# ## Input extra relevant information in the vector store embeddings for use as context
# It will be good to improve the context that the model has access to, especially for financial report terms and definitions.
# Here, we add the internal document with the information of finance terms into the vector store embeddings to be used by the LLM.

# %%
# tesla document embeddings
FILE_PATH = "../data/Tesla_Annual_Report_2022.pdf"
loader = PyPDFLoader(FILE_PATH)
data = loader.load()
embeddings = OpenAIEmbeddings()
vector_store = FAISS.from_documents(data, embeddings)

# %%
# financial terms embedding
FILE_PATH = "../data/Glossary of financial terms.pdf"
loader = PyPDFLoader(FILE_PATH)
data = loader.load()
embeddings = OpenAIEmbeddings()
vbase = FAISS.from_documents(data, embeddings)

# %%
vbase.save_local("../faiss store/financial_terms_embedding")

# %%
vbase_load = FAISS.load_local("../faiss store/financial_terms_embedding", embeddings)

# %%
vbase_load.merge_from(vector_store)

# %%
final_store = vbase_load

# %%
final_store.docstore._dict
# Out:
# {'f61bfd22-ae57-4150-b619-d9ef8b504bde': Document(page_content='Services, Projects & Operations » Financial Management » Essential Information » Glossary of Financial Terms\nGlossary of Financial Terms\nHave you ever found yourself a little bamboozled by the terminology used in financial activities? If so, use this glossary to\nkeep you on track.\nBasic Financial Terms\nSome of the more straightforward financial terms that you might come across are listed below.\nAccounting Manual:\n A document that details the accounting policies and procedures of a business. It normally contains\na list of account codes or chart of accounts. The way a company treats depreciation is an example of an accounting\npolicy which would be set out in the accounting manual.\nAccounting Period:\n The period for which a company prepares its accounts. Management accounts may be produced\ninternally on a monthly or quarterly basis, whilst financial accounts will be made for a period of one year. An accounting\nperiod starts when a company begins trading and ends either:\none year after starting to trade\nat the end of the period of account, or\nat the start of a winding-up of operations\nAccounts:\n The documents prepared by accountants which give an indication of how a business has performed over a\nspecified period (usually a year).\nAccounts Payable (or Creditors):\n The debts shown on the balance sheet of a buyer, when goods or services have\nbeen bought on credit.\nAccounts Receivable (or Debtors):\n The money owed by customers when they have been sold goods or services on\ncredit.\nAccruals:\n Provisions for liaibilities incurred in an accounting period for which an invoice has not been received.\nAccruals Basis:\n A process of revenue calculation that disregards the receiving or dispersal of cash. Instead, services\nalready rendered are recognised as revenue, and services utilised (or efforts expended) are registered as expenses.\nBook Value:\n The amount of money at which an asset is recorded in the financial statements.\nAvoidable Cost:\n Costs not continuing if an operation is deleted or modified.\nBalance Sheet:\n A statement of financial status at a given point in time.\nBudget:\n A plan of action expressed in quantitative monetary terms, i.e. a statement of how much money you will allocate\nto different items or activities that you or your team will undertake.\nCapital:\n Most commonly refers to owner’s equity i.e. the money owners have put into the business.\nCapital Cost:\n A capital cost is the cost of purchasing a fixed asset.\nCapital Expenditure (or Capex):\n Money spent on a major project or asset, such as premises. Capital expenditure is\ngiven a value on the balance sheet rather than being written off to the Profit and Loss Account.\nCash Basis:\n An accounting process where the timing of cash receipts and payments is the sole calculating factor when\ndetermining income and expenses.\nCash Budget:\n A statement of planned cash receipts and payments.\nCash Flow Forecast:\n A cash flow forecast is a way of projecting the likely cash that will flow through the organisation\nand is useful for predicting any shortfalls that may arise. It is different to the P&L as it shows only cash and it records the\nlikely timing of cash payments and receipts, usually on a monthly basis. The P&L shows income and expenditure in the\nperiod when an invoice is issued or received, not when the actual cash is physically received or paid out.\nContribution Margin:\n Revenue from sales, minus all variable costs.\nCost:\n Financial sacrifice made for goods or services. May be outlay or opportunity costs.', metadata={'source': '../data/Glossary of financial terms.pdf', 'page': 0}),
#  '9cc43a5d-2206-43be-a31c-a4a59399d810': Document(page_content='Cost Centre:\n The small responsibility centre for costs. For instance, this could be a department or even a sub-division of\na department like a particular assembly line within an assembly department.\nCost of Goods Sold:\n Cost of acquired and resold merchandise.\nCost of Sales:\n Synonymous with cost of goods sold.\nCurrent Assets:\n Cash plus assets that are likely to be converted to cash within the operating cycle (usually within one\nyear).\nCurrent Liabilities:\n Existing debts that will be due to be paid within either the coming year.\nDepreciation:\n Depreciation spreads the cost of using an asset over the length of time which it is in use. This cost is\ncalculated as the cost of purchase less the resale value at the end of the useful economic life.\nDividend:\n A way of distributing the profits of a business amongst its shareholders. If a dividend is paid, it is usually paid\nannually.\nEarnings:\n The excess of revenues over expenses.\nExpense:\n A gross decrease in assets from the purchasing of goods and services.\nFixed Assets:\n An item that is purchased by your organisation for use in its operations. You will be able to use it for more\nthan a year as it shouldn’t wear out or end up being of no benefit to you before the 12 months is up.\nTangible Fixed Assets:\n Physical assets, also referred to as ‘property, plant and equipment’, or ‘plant assets’.\nFixed Cost:\n A cost that is not affected by a change of related total activity or volume during a set time period. A cost is\nfixed if it will not vary with the level of work or production that is taking place, during a given period of time.\nGoodwill:\n The value of a business over and above its net tangible assets. This value is derived largely from the market\nvalue\nGross Profit:\n The profits made by a business before overheads and other fixed costs. Essentially gross profit = goods\nsold - cost of goods sold.\nIncome:\n The excess of revenues over expenses. Income and cash are different things. Income is another word for the\nsales that have been invoiced or funding that has been awarded. Cash is the physical money going into your\norganisation’s bank account when the invoice or funding is paid.\nIntangible Assets:\n A class of non-physical, long-lived assets, e.g. patents and trademarks.\nLiabilities:\n The money that an organisation is commited to pay another at some point in the future.\nLosses:\n The opposite of profits i.e. when an organisation spends more than it earns.\nManagement Accounts:\n Accounts which are prepared for use when managing the business.\nNet Income:\n The calculation for a given period of time which registers the excess of revenues and gains over expenses\nand losses.\nNet Current Assets:\n Current assets minus current liabilities.\nNet Profit:\n The total profit made by the business after overheads and other fixed costs have been deducted, but before\nany dividends and tax payments have been made.\nOperating Cycle:\n The time span during which cash paid for acquisitions ultimately results in cash paid by purchasers.\nThe cycle runs as follows: cash spent on acquisitions that are used to produce output, which is sold to customers, who\npay cash for their purchases.\nOpportunity Cost:\n The potential contribution to profit foregone in order to utilise limited resources in another area.\nPayback Period:\n The amount of time taken to recoup, in terms of cash inflows, the initial amount of outlay.\nPrime Costs:\n Direct-material cost plus direct-labour cost.\nProduct Costs:\n Costs identified with goods produced, or goods purchased for resale.', metadata={'source': '../data/Glossary of financial terms.pdf', 'page': 1}),
#  '8e257623-b110-419b-8fb8-66f90a3608a6': Document(page_content='Profit:\n The capital left in the business when all liabilities have been met.\nProfit and Loss Account (or P&L):\n The P&L allows you to understand whether, over a chosen period of time (often a\nmonth or year), the income of an organisation has been greater than the expenditure. In other words, it shows whether\nthe organisation is making a profit/surplus or a loss/deficit.\nRevenue Cost:\n The cost of purchasing an item for use within your organisation. The item is useful to your organisation\nfor a year or less. It will be used up or stop being of benefit by the time 12 months is up.\nStraight-Line Depreciation:\n A calculation of depreciation that allocates the same cost to an asset for each successive\nyear of its useful life.\nSunk Cost:\n Also referred to as ‘historical cost’, this is a cost that has already been incurred, and is therefore irrelevant to\nthe future decision-making process.\nTangible Assets:\n An asset that can be touched and seen, such as land and buildings, fixtures and fittings.\nTransfer Price:\n The amount charged for a product or service provided by one segment of an organisation, to another\nsegment within that same organisation. Transfer prices are prices charged internally, between different parts of the same\norganisation, for services or products.\nUncontrollable Cost:\n A cost that, within a given time span, cannot be affected by the efforts of the manager of a\nresponsibility centre.\nVariable Cost:\n A cost that changes in total in direct proportion to changes in the related total activity or volume. A\nvariable cost varies in direct proportion to activity.\nVariance:\n The unexpected deviation of actual results from those budgeted or expected.\nWorking Capital:\n Current assets and current liabilities i.e the amount of money tied up in the day to day operations of\nthe business.\nZero-Base Budgeting (or ZBB):\n A budgeting practice in which managers are asked to justify all of their activities as if\nthey were being undertaken for the first time.\nRelated Items\nRelated Resources\nAn Introduction to the Key Financial Documents\nFinance Fundamentals: Internet Links and References', metadata={'source': '../data/Glossary of financial terms.pdf', 'page': 2}),
#  'f3982e1b-b764-4c4b-a4c8-578d45a75578': Document(page_content='Annual Report\n2022\nTesla, Inc.   |  1 Tesla Road, Austin, TX 78725  |  www.tesla.com', metadata={'source': '../data/Tesla_Annual_Report_2022.pdf', 'page': 0}),
#  'e9465062-1b93-47b8-983d-5d83be13b3e3': Document(page_content='', metadata={'source': '../data/Tesla_Annual_Report_2022.pdf', 'page': 1}),
#  '63710a66-ce08-4d7b-b6a7-46bc576b167e': Document(page_content='NOTICE OF 2023 A NNUAL MEETING\nOFSTOCKHOLDERS\nTOBEHELD ON MAY16, 2023\nDear Tesla Stockholders:\nWe are pleased to inform you that our 2023 Annual Meeting of Stockholders (the “2023 Annual Meeting”) will be held on\nTuesday, May 16, 2023, at 3:00 p.m. Central Time, both virtually via the Internet at www.meetnow.global/TESLA2023 and in\nperson for a limited number of stockholders at Tesla’s Gigafactory Texas located at 1 Tesla Road, Austin, TX 78725. For your\nconvenience, we will also webcast the 2023 Annual Meeting live via the Internet at www.tesla.com/2023shareholdermeeting.The agenda of the 2023 Annual Meeting will be the following items of business, which are more fully described in this proxystatement:\nAgenda Item Board Vote Recommendation\nTesla Proposals\n1. A Tesla proposal to elect three Class I directors to serve for a term of three\nyears, or until their respective successors are duly elected and qualified(“Proposal One”).“FOR EACH COMPANY NOMINEE ”\n2. A Tesla proposal to approve executive compensation on a non-binding\nadvisory basis (“Proposal Two”).“FOR”\n3. A Tesla proposal to approve the frequency of future votes on executive\ncompensation on a non-binding advisory basis (“Proposal Three”).“EVERY THREE YEARS ”\n4. A Tesla proposal to ratify the appointment of PricewaterhouseCoopers LLP as\nTesla’s independent registered public accounting firm for the fiscal year endingDecember 31, 2023 (“Proposal Four”).“FOR”\nStockholder Proposals\n5. A stockholder proposal regarding reporting on key-person risk, if properly\npresented (“
be\npresent in person or virtually via the Internet at the 2023 Annual Meeting or (2) have properly submitted a proxy inorder to constitute a quorum at the 2023 Annual Meeting.\nUnder the General Corporation Law of the State of Delaware, abstentions and broker “non-votes” are counted as\npresent, and therefore are included for the purposes of determining whether a quorum is present at the 2023 AnnualMeeting. A broker “non-vote” occurs when an organization that is the stockholder of record that holds shares for abeneficial owner, and which is otherwise counted as present or represented by proxy, does not vote on a particularproposal because that organization does not have discretionary voting power under applicable regulations to vote onthat item and has not received specific voting instructions from the beneficial owner.\nQ: What proposals will be voted on at the 2023 Annual Meeting?\nA: The proposals scheduled to be voted on at the 2023 Annual Meeting are:\nTesla Proposals\n››A Tesla proposal to elect three Class I directors listed in this proxy statement to serve for a term of three years,\nor until their respective successors are duly elected and qualified (Proposal One);\n››A Tesla proposal to approve executive compensation on a non-binding advisory basis (Proposal Two);\n››A Tesla proposal to approve the frequency of future votes on executive compensation on a non-binding\nadvisory basis (Proposal Three);\n››A Tesla proposal to ratify the appointment of PricewaterhouseCoopers LLP as Tesla’s independent regist ...
#  '80920199-8a49-431f-a528-be90bd0b5910': Document(page_content='Q: What is the voting requirement to approve each of the proposals?\nA:\nProposal Vote RequiredBroker\nDiscretionary\nVoting Allowed\nProposal One—Tesla proposal to\nelect three Class I directorsMajority of the shares present in\nperson or represented by proxyand entitled to vote on theelection of directorsNo\nProposal Two—Tesla proposal to\napprove executive compensation ona non-binding advisory basisMajority of the shares present in\nperson or represented by proxyand entitled to vote on the subjectmatterNo\nProposal Three—Tesla proposal to\napprove the frequency of futurevotes on executive compensation ona non-binding advisory basisThe frequency (every one, two or\nthree years) receiving the mostvotes will be considered thefrequency recommended bystockholdersNo\nProposal Four—Tesla proposal to\nratify the appointment ofindependent registered publicaccounting firmMajority of the shares present in\nperson or represented by proxyand entitled to vote on the subjectmatterYes\nProposal Five—Stockholder proposal\nregarding reporting on key-personrisk, if properly presentedMajority of the shares present in\nperson or represented by proxyand entitled to vote on the subjectmatterNo\nQ: How are votes counted?\nA: All shares entitled to vote and that are voted in person at the 2023 Annual Meeting will be counted, and all shares\nrepresented by properly executed and unrevoked proxies received prior to the 2023 Annual Meeting will be voted at the2023 Annual Meeting as indicated in such proxies. You may vote “ FOR,” “AGAINST ”o r“ ABSTAIN ” on each of the\nnominees for election as director (Proposal One), and on each of Proposals Two, Four and Five. You may vote torecommend, by non-binding vote, the frequency of future executive compensation votes (Proposal Three) for a voteevery one, two or three years, or you may abstain from voting.\nWith respect to the election of directors, Tesla’s bylaws provide that in an uncontested election, the affirmative vote of\na majority of the shares present in person or represented by proxy at the meeting and entitled to vote on the matter isrequired to elect a director. Abstentions with respect to any director nominee (Proposal One) or any of Proposals Two,Four and Five will have the same effect as a vote against such nominee or Proposal. Consequently, each directornominee will be elected, and each of Proposals Two, Four and Five will be approved or ratified, as applicable, only if thenumber of shares voted “ FOR” such nominee or Proposal exceeds the total number of shares voted “ AGAINST ”o rt o\n“ABSTAIN ” with respect to such nominee or Proposal.\nYou may vote to recommend, by non-binding vote, the frequency of future executive compensation votes (Proposal\nThree) for a vote every one, two or three
metadata={'source': '../data/Tesla_Annual_Report_2022.pdf', 'page': 178}),
#  '15e707db-2f11-4a42-8bb7-7da3f74ec612': Document(page_content='106Exhibit Incorporated by Reference Filed\nNumber Exhibit Description Form File No. Exhibit Filing Date Herewith\n21.1 List of Subsidiaries of the Registrant — — — — X\n23.1 Consent of PricewaterhouseCoopers LLP,\nIndependent Registered Public Accounting Firm— — — — X\n31.1 Rule 13a-14(a) / 15(d)-14(a) Certification of\nPrincipal Executive Officer— — — — X\n31.2 Rule 13a-14(a) / 15(d)-14(a) Certification of\nPrincipal Financial Officer— — — — X\n32.1* Section 1350 Certifications — — — — X\n101.INS Inline XBRL Instance Document —— — — X\n101.SCH Inline XBRL Taxonomy Extension Schema\nDocument—— — — X\n101.CAL Inline XBRL Taxonomy Extension Calculation\nLinkbase Document.—— — — X\n101.DEF Inline XBRL Taxonomy Extension Definition\nLinkbase Document—— — — X\n101.LAB Inline XBRL Taxonomy Extension Label\nLinkbase Document—— — — X\n101.PRE Inline XBRL Taxonomy Extension Presentation\nLinkbase Document—— — — X\n104 Cover Page Interactive Data File (formatted as\ninline XBRL with applicable taxonomyextension information contained in Exhibits101)\n* Furnished herewith\n** Indicates a management contract or compensatory plan or arrangement\n† Confidential treatment has been requested for portions of this exhibit\n†† Portions of this exhibit have been redacted in compliance with Regulation S-K Item 601(b)(10).\n(1) Indicates a filing of SolarCity\n(2) Indicates a filing of Maxwell Technologies, Inc.\nITEM 16. SUMMARY\nNone.', metadata={'source': '../data/Tesla_Annual_Report_2022.pdf', 'page': 179}),
#  'a2a6c161-8cde-4fff-8c94-dd8b1b6ae20e': Document(page_content='107SIGNATURES\nPursuant to the requirements of Section 13 or 15(d) the Securities Exchange Act of 1934, the registrant has duly caused this\nreport to be signed on its behalf by the undersigned, thereunto duly authorized.\nTesla, Inc.\nDate: January 30, 2023 /s/ Elon Musk\nElon Musk\nChief Executive Officer\n(Principal Executive Officer)\nPursuant to the requirements of the Securities Exchange Act of 1934, this report has been signed below by the following persons\non behalf of the registrant and in the capacities and on the dates indicated.\nSignature Title Date\n/s/ Elon MuskChief Executive Officer and Director (Principal Executive\nOfficer) January 30, 2023\nElon Musk\n/s/ Zachary J. Kirkhorn Chief Financial Officer (Principal Financial Officer) January 30, 2023\nZachary J. Kirkhorn\n/s/ Vaibhav Taneja Chief Accounting Officer (Principal Accounting Officer) January 30, 2023\nVaibhav Taneja\n/s/ Robyn Denholm Director January 30, 2023\nRobyn Denholm\n/s/ Ira Ehrenpreis Director January 30, 2023\nIra Ehrenpreis\n/s/ Joseph Gebbia Director January 30, 2023\nJoseph Gebbia\n/s/ Hiromichi Mizuno Director January 30, 2023\nHiromichi Mizuno\n/s/ James Murdoch Director January 30, 2023\nJames Murdoch\n/s/ Kimbal Musk Director January 30, 2023\nKimbal Musk\n/s/ Kathleen Wilson-Thompson Director January 30, 2023\nKathleen Wilson-Thompson', metadata={'source': '../data/Tesla_Annual_Report_2022.pdf', 'page': 180}),
#  'b6408a2b-e3ec-4852-8d87-e9f6176e0fc6': Document(page_content='[THIS PAGE INTENTIONALLY LEFT BLANK]', metadata={'source': '../data/Tesla_Annual_Report_2022.pdf', 'page': 181}),
#  'fcca849a-36c7-4d23-8d31-9ce0ecb394b9': Document(page_content='', metadata={'source': '../data/Tesla_Annual_Report_2022.pdf', 'page': 182}),
#  '97cf1426-9400-4dc4-a987-8b440d76c967': Document(page_content='Tesla, Inc.   |  1 Tesla Road, Austin, TX 78725  |  www.tesla.com', metadata={'source': '../data/Tesla_Annual_Report_2022.pdf', 'page': 183})}
